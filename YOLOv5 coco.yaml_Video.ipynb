# %%
# !pip install pyqt5
# Out:
# ...
#      |████████████████████████████████| 76.6MB 60kB/s
# ...
#      |████████████████████████████████| 286kB 38.7MB/s
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 2395, done.
# remote: Total 2395 (delta 0), reused 0 (delta 0), pack-reused 2395
# Receiving objects: 100% (2395/2395), 5.26 MiB | 8.08 MiB/s, done.
# Resolving deltas: 100% (1577/1577), done.

# %%
# !pip install -U -r yolov5/requirements.txt
# Out:
# Requirement already up-to-date: Cython in /usr/local/lib/python3.6/dist-packages (from -r yolov5/requirements.txt (line 4)) (0.29.21)
# ...
#      |████████████████████████████████| 11.6MB 257kB/s
# ...
#      |████████████████████████████████| 14.5MB 236kB/s
# ...
#      |████████████████████████████████| 49.4MB 60kB/s
# ...
#      |████████████████████████████████| 2.2MB 32.7MB/s
# ...
#      |████████████████████████████████| 276kB 40.3MB/s
# ...
#      |████████████████████████████████| 25.9MB 117kB/s
# Requirement already up-to-date: tensorboard>=2.2 in /usr/local/lib/python3.6/dist-packages (from -r yolov5/requirements.txt (line 11)) (2.3.0)
# Requirement already up-to-date: torch>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from -r yolov5/requirements.txt (line 12)) (1.6.0+cu101)
# Requirement already up-to-date: torchvision>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from -r yolov5/requirements.txt (line 13)) (0.7.0+cu101)
# ...
#      |████████████████████████████████| 71kB 9.0MB/s
# ...

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
import torch
from IPython.display import Image
from utils.google_utils import gdrive_download

print('torch %s %s' %(torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# torch 1.6.0+cu101 _CudaDeviceProperties(name='Tesla K80', major=3, minor=7, total_memory=11441MB, multi_processor_count=13)

# %%
# !python train.py --img 800 --batch 16 --epochs 500  --data ./data/coco128.yaml --cfg ./models/yolov5s.yaml --weights ''
# Out:
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=False, cfg='./models/yolov5s.yaml', data='./data/coco128.yaml', device='', epochs=500, evolve=False, global_rank=-1, hyp='data/hyp.scratch.yaml', img_size=[800, 800], local_rank=-1, logdir='runs/', multi_scale=False, name='', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=16, weights='', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/", view at http://localhost:6006/
# 2020-08-28 09:02:38.301309: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !ls
# Out:
# data	    hubconf.py	models	     requirements.txt  train.py        weights
# detect.py   inference	__pycache__  runs	       tutorial.ipynb
# Dockerfile  LICENSE	README.md    test.py	       utils

# %%
# !mkdir test

# %%
# %cd test
# Out:
# /content/yolov5/test

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bd91f453-29a3-472a-b4c5-d5d2ef1bdfdc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bd91f453-29a3-472a-b4c5-d5d2ef1bdfdc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ex1.mp4 to ex1.mp4

# %%
# !ls
# Out:
# ex1.mp4

# %%
# %cd ..
# Out:
# /content/yolov5

# %%
# !python detect.py --weights ./runs/exp0/weights/best.pt --conf 0.4 --source test/result.mp4 --output inference/output
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', img_size=640, iou_thres=0.5, output='inference/output', save_txt=False, source='test/result.mp4', update=False, view_img=False, weights=['./runs/exp0/weights/best.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# Fusing layers...
# Model Summary: 140 layers, 7.45958e+06 parameters, 6.61683e+06 gradients
# video 1/1 (1/514) /content/yolov5/test/result.mp4: 384x640 1 persons, Done. (0.033s)
# video 1/1 (2/514) /content/yolov5/test/result.mp4: 384x640 2 persons, Done. (0.032s)
# video 1/1 (3/514) /content/yolov5/test/result.mp4: 384x640 1 persons, Done. (0.032s)
# video 1/1 (4/514) /content/yolov5/test/result.mp4: 384x640 1 persons, Done. (0.029s)
# video 1/1 (5/514) /content/yolov5/test/result.mp4: 384x640 1 persons, Done. (0.029s)
# video 1/1 (6/514) /content/yolov5/test/result.mp4: 384x640 1 persons, Done. (0.030s)
# ...

# %%
# !ls
# Out:
# ex1.mp4

# %%
# %cd inference
# Out:
# /content/yolov5/inference

# %%
# %cd output
# Out:
# /content/yolov5/inference/output

# %%
# %cd ..
# Out:
# /content/yolov5
